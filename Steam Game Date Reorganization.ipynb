# %%
import pandas as pd
import numpy as np 
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
games = pd.read_csv('steam-200k.csv')
games = games.rename({'151603712':'userId', 'The Elder Scrolls V Skyrim': 'gameName', '1.0':'Actions'}, axis = 1)
games.drop(['0'],axis = 1, inplace = True)

# %% [markdown]
# get a sense of the data

# %%
print("number of distinct users = %d" %games['userId'].nunique()) 
print("number of distinct games = %d" %games['gameName'].nunique()) 
games.head()
# Out:
# number of distinct users = 12393
# number of distinct games = 5155
#       userId                    gameName  purchase  Actions
# 0  151603712  The Elder Scrolls V Skyrim      play    273.0
# 1  151603712                   Fallout 4  purchase      1.0
# 2  151603712                   Fallout 4      play     87.0
# 3  151603712                       Spore  purchase      1.0
# 4  151603712                       Spore      play     14.9

# %%
# checking missing data in games 
total = games.isnull().sum().sort_values(ascending = False) # total number of missing values
percent = (games.isnull().sum()/games.isnull().count()*100).sort_values(ascending = False)
missing_games_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_games_data.head()
# Out:
#           Total  Percent
# Actions       0      0.0
# purchase      0      0.0
# gameName      0      0.0
# userId        0      0.0

# %% [markdown]
# we want to format data in a way such that each row get distinct pair of userId and gameName

# %%
games.head()
# Out:
#       userId                    gameName  purchase  Actions
# 0  151603712  The Elder Scrolls V Skyrim      play    273.0
# 1  151603712                   Fallout 4  purchase      1.0
# 2  151603712                   Fallout 4      play     87.0
# 3  151603712                       Spore  purchase      1.0
# 4  151603712                       Spore      play     14.9

# %%
# split the purchase column to two dataframes and perform an outer join to group highly duplicated row
games_temp = games[games['purchase'] == 'play']
games_temp =games_temp.rename({'purchase':'play'}, axis = 1)
games = games[games.purchase =='purchase']
games.drop(columns = 'Actions', inplace = True)
result = pd.merge(games,games_temp, how='outer', on=['userId','gameName'])

# %%
# reindex to group the data associated with the same user together
reindex_result = result.sort_values(by = 'userId')
reindex_result.set_index(np.arange(len(reindex_result.index)))
# Out:
#            userId                                     gameName  purchase  \
# 0            5250                                     Portal 2  purchase
# 1            5250                              Cities Skylines  purchase
# 2            5250                     Deus Ex Human Revolution  purchase
# 3            5250                                  Alien Swarm  purchase
# 4            5250                              Team Fortress 2  purchase
# 5            5250                                       Dota 2  purchase
# 6            5250                               Counter-Strike  purchase
# 7            5250                        Counter-Strike Source  purchase
# 8            5250                                Day of Defeat  purchase
# 9            5250                                    Half-Life  purchase
# 10           5250                                  Half-Life 2  purchase
# 11           5250                           Deathmatch Classic  purchase
# 12           5250                      Half-Life 2 Episode One  purchase
# 13           5250                      Half-Life 2 Episode Two  purchase
# 14           5250                       Half-Life 2 Lost Coast  purchase
# 15           5250                         Half-Life Blue Shift  purchase
# 16           5250                     Half-Life Opposing Force  purchase
# 17           5250                                       Portal  purchase
# 18           5250                                     Ricochet  purchase
# 19           5250                        Team Fortress Classic  purchase
# 20           5250                       Half-Life 2 Deathmatch  purchase
# 21          76767                        Counter-Strike Source  purchase
# 22          76767                                   Thief Gold  purchase
# 23          76767                               Counter-Strike  purchase
# 24          76767                    Call of Duty World at War  purchase
# 25          76767  Call of Duty Modern Warfare 2 - Multiplayer  purchase
# 26          76767                Call of Duty Modern Warfare 2  purchase
# 27          76767                                     Banished  purchase
# 28          76767                             Total War ATTILA  purchase
# 29          76767                Call of Duty Modern Warfare 3  purchase
# ...           ...                                          ...       ...
# 129505  309058572                                       Dota 2  purchase
# 129506  309107542                                       Dota 2  purchase
# 129507  309138595                                       Dota 2  purchase
# 129508  309167186                                     Portal 2  purchase
# 129509  309181805                                   Brawlhalla  purchase
# 129510  309181805                               Apotheon Arena  purchase
# 129511  309188905                 Counter-Strike Nexon Zombies  purchase
# 129512  309188905                                     Unturned  purchase
# 129513  309213952                                       Dota 2  purchase
# 129514  309216884                                       Dota 2  purchase
# 129515  309228590                                       Dota 2  purchase
# 129516  309255941                            Mitos.is The Game  purchase
# 129517  309262440                          CrimeCraft GangWars  purchase
# 129518  309262440             A.V.A - Alliance of Valiant Arms  purchase
# 129519  309262440                              Team Fortress 2  purchase
# 129520  309265377                                   Brawlhalla  purchase
# 129521  309265377                             MicroVolts Surge  purchase
# 129522  309375103                      East India Company Gold  purchase
# 129523  309404240                            Mitos.is The Game  purchase
# 129524  309404240                                     Unturned  purchase
# 129525  309404240                                 Transformice  purchase
# 129526  309404240                         AdVenture Capitalist  purchase
# 129527  309404240                              Team Fortress 2  purchase
# 129528  309434439                                       Dota 2  purchase
# 129529  309554670                            Mitos.is The Game  purchase
# 129530  309626088                 Age of Empires II HD Edition  purchase
# 129531  309812026                                    Robocraft  purchase
# 129532  309812026                 Counter-Strike Nexon Zombies  purchase
# 129533  309824202                                       Dota 2  purchase
# 129534  309903146                                       Dota 2  purchase
#
#         play  Actions
# 0       play     13.6
# 1       play    144.0
# 2       play     62.0
# 3       play      4.9
# 4       play      0.8
# 5       play      0.2
# 6        NaN      NaN
# 7        NaN      NaN
# 8        NaN      NaN
# 9        NaN      NaN
# 10       NaN      NaN
# 11       NaN      NaN
# 12       NaN      NaN
# 13       NaN      NaN
# 14       NaN      NaN
# 15       NaN      NaN
# 16       NaN      NaN
# 17       NaN      NaN
# 18       NaN      NaN
# 19       NaN      NaN
# 20       NaN      NaN
# 21      play     25.0
# 22       NaN      NaN
# 23      play    365.0
# 24      play    271.0
# 25      play    165.0
# 26      play     65.0
# 27      play     24.0
# 28      play    207.0
# 29      play     15.9
# ...      ...      ...
# 129505  play      5.2
# 129506  play      6.7
# 129507  play      0.8
# 129508  play      1.1
# 129509  play      3.2
# 129510   NaN      NaN
# 129511  play      6.1
# 129512  play      0.8
# 129513  play     13.8
# 129514  play      4.0
# 129515  play      0.3
# 129516  play      5.7
# 129517   NaN      NaN
# 129518   NaN      NaN
# 129519  play      1.2
# 129520  play      2.0
# 129521  play      0.8
# 129522   NaN      NaN
# 129523  play      2.2
# 129524  play     13.0
# 129525  play      0.3
# 129526  play      0.7
# 129527  play      2.2
# 129528  play      0.8
# 129529  play      5.9
# 129530  play      6.7
# 129531   NaN      NaN
# 129532   NaN      NaN
# 129533  play      0.7
# 129534  play      0.2
#
# [129535 rows x 5 columns]

# %%
save the cleaned data to a pickle file
# Out:
# 'cleaned data to a pickle file' was not found in history, as a file, url, nor in the user namespace.

# %%
reindex_result.to_pickle('clean_steam_data.pkl')
