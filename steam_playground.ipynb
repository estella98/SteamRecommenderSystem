# %% [markdown]
# ## Simple Recommenders on Steam Games Data
#
# In this notebook we try out two different recommenders on [Steam dataset on Kaggle](https://www.kaggle.com/tamber/steam-video-games). We will use:
# - ```pyspark``` for preprocessing
# - ```turicreate``` for building an item-item similarity recommender
# - ```pyspark.ml``` for building an ALS-based recommender
#
# The dataset has no header but comes in 5 columns:
# - User ID: integer
# - Game title: string
# - Activity: string (purchase/play)
# - Status: float (1.0 if activity is purchase, total number of hours in game if activity is play)
# - A column full of 0's, will discard

# %%
import pandas as pd
import turicreate as tc
import pyspark.sql.functions as F
from pyspark.sql.window import Window
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### First load the data and gather some basic stats

# %%
# pyspark's way of load csv to dataframe
input_df = sqlContext.read.format("csv") \
  .option("header", False) \
  .option("inferSchema", True) \
  .load("dbfs:/FileStore/tables/steam_200k-30fe6.csv") \
  .drop(F.col("_c4"))

# Rename the columns to something meaningful
steam_df = input_df.selectExpr("_c0 as user", "_c1 as game", "_c2 as activity", "_c3 as hours_played")

# shows first 1k rows
# this is a function provided by Databricks
# use .show() instead for spark
display(steam_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user</th><th>game</th><th>activity</th><th>hours_played</th></tr></thead><tbody><tr><td>151603712</td><td>The Elder Scrolls V Skyrim</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>The Elder Scrolls V Skyrim</td><td>play</td><td>273.0</td></tr><tr><td>151603712</td><td>Fallout 4</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Fallout 4</td><td>play</td><td>87.0</td></tr><tr><td>151603712</td><td>Spore</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Spore</td><td>play</td><td>14.9</td></tr><tr><td>151603712</td><td>Fallout New Vegas</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Fallout New Vegas</td><td>play</td><td>12.1</td></tr><tr><td>151603712</td><td>Left 4 Dead 2</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Left 4 Dead 2</td><td>play</td><td>8.9</td></tr><tr><td>151603712</td><td>HuniePop</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>HuniePop</td><td>play</td><td>8.5</td></tr><tr><td>151603712</td><td>Path of Exile</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Path of Exile</td><td>play</td><td>8.1</td></tr><tr><td>151603712</td><td>Poly Bridge</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Poly Bridge</td><td>play</td><td>7.5</td></tr><tr><td>151603712</td><td>Left 4 Dead</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Left 4 Dead</td><td>play</td><td>3.3</td></tr><tr><td>151603712</td><td>Team Fortress 2</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Team Fortress 2</td><td>play</td><td>2.8</td></tr><tr><td>151603712</td><td>Tomb Raider</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Tomb Raider</td><td>play</td><td>2.5</td></tr><tr><td>151603712</td><td>The Banner Saga</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>The Banner Saga</td><td>play</td><td>2.0</td></tr><tr><td>151603712</td><td>Dead Island Epidemic</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Dead Island Epidemic</td><td>play</td><td>1.4</td></tr><tr><td>151603712</td><td>BioShock Infinite</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>BioShock Infinite</td><td>play</td><td>1.3</td></tr><tr><td>151603712</td><td>Dragon Age Origins - Ultimate Edition</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Dragon Age Origins - Ultimate Edition</td><td>play</td><td>1.3</td></tr><tr><td>151603712</td><td>Fallout 3 - Game of the Year Edition</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Fallout 3 - Game of the Year Edition</td><td>play</td><td>0.8</td></tr><tr><td>151603712</td><td>SEGA Genesis & Mega Drive Classics</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>SEGA Genesis & Mega Drive Classics</td><td>play</td><td>0.8</td></tr><tr><td>151603712</td><td>Grand Theft Auto IV</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Grand Theft Auto IV</td><td>play</td><td>0.6</td></tr><tr><td>151603712</td><td>Realm of the Mad God</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Realm of the Mad God</td><td>play</td><td>0.5</td></tr><tr><td>151603712</td><td>Marvel Heroes 2015</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Marvel Heroes 2015</td><td>play</td><td>0.5</td></tr><tr><td>151603712</td><td>Eldevin</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Eldevin</td><td>play</td><td>0.5</td></tr><tr><td>151603712</td><td>Dota 2</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Dota 2</td><td>play</td><td>0.5</td></tr><tr><td>151603712</td><td>BioShock</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>BioShock</td><td>play</td><td>0.5</td></tr><tr><td>151603712</td><td>Robocraft</td><td>purchase</td><td>1.0</td></tr><tr><td>151603712</td><td>Robocraft</td><td>play</td><td>0.4</td></tr><t ...

# %% [markdown]
# The ```activity``` column has only 2 distinct values: purchase and play. We can separate them into their own columns and examine their values.

# %%
# Spark uses lazy evaluation so transformations on a dataframe are
# only executed when an action (to return some results) is called on
# the dataframe. You can choose to persist a calculated dataframe in
# memory by doing below so future calculations on it would be fast.

steam_df.cache()

# Keep only the records with "purchase"
# drop unneeded column (original activity column)
# and remove duplicated rows

purchase_df = steam_df.filter(F.col("activity") == "purchase") \
  .withColumnRenamed("hours_played", "purchase") \
  .drop(F.col("activity")) \
  .dropDuplicates()

# same as above for activity "play"

play_df = steam_df.filter(F.col("activity") == "play") \
  .withColumnRenamed("hours_played", "play") \
  .drop(F.col("activity")) \
  .dropDuplicates()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Spark offers a convenient method on dataframe called ```summary()```, which returns a dataframe on simple summarizing stats on numerical columns.

# %%
purchase_df.cache()
play_df.cache()

purchase_summary = purchase_df.select("purchase").summary()
play_summary = play_df.select("play").summary()

summary_stats = purchase_summary.join(play_summary, ["summary"], how="left")

display(summary_stats)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>purchase</th><th>play</th></tr></thead><tbody><tr><td>count</td><td>128804</td><td>70489</td></tr><tr><td>mean</td><td>1.0</td><td>48.87806324391041</td></tr><tr><td>stddev</td><td>0.0</td><td>229.33523599681294</td></tr><tr><td>min</td><td>1.0</td><td>0.1</td></tr><tr><td>25%</td><td>1.0</td><td>1.0</td></tr><tr><td>50%</td><td>1.0</td><td>4.5</td></tr><tr><td>75%</td><td>1.0</td><td>19.1</td></tr><tr><td>max</td><td>1.0</td><td>11754.0</td></tr></tbody></table></div>

# %% [markdown]
# #### Some obervations
#
# Above summary shows that ```purchase``` has only a single value 1.0. We will **not** include purchase status in building our recommender, for two reasons:
# 1. number of hours played is more interesting to look at - it is an implicit feedback of the user's preference for games he/she has purchased
# 2. if using [Jaccard similarity](https://apple.github.io/turicreate/docs/api/generated/turicreate.recommender.item_similarity_recommender.ItemSimilarityRecommender.html) when measuring the similarity between two sets of elements, the number of hours played are treated as binary purchase status (1/0)
#
# For ```play``` column, the data is heavily skewed and has a large range. There are different ways to do normalization. Since we are going to use it to represent the user's ranking of preference within his / her own purchases, let's convert it to the percentage of hours each user spends on each game he / she owns.
#
# But before doing that, notice there are 128804 purchase records and only 70489 play records, meaning some users bought certain games but never played them. We need to find a score for those less-favoured games too. To differentiate them from the games that a user has never bought, we can impute the corresponding play fields with a small value less than the min 0.1, say 0.05. Then we can move on to calculate the percentage as planned.

# %%
imputed_df = purchase_df.join(play_df, ["user", "game"], how="left") \
  .na.fill(0.05, ["play"]) \
  .drop(F.col("purchase")) \
  .dropDuplicates()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(imputed_df.distinct().count())
print(purchase_df.distinct().count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">128816
# 128804
# </div>

# %% [markdown]
# So there is a bit of problem here - while we expect to have 128804 rows in the new dataframe after left join, we ended up with 128816 records. Those extra 12 rows could be duplicates with minor discrepencies in the records. They can be located by assigning an index to each row.

# %%
imputed_df.cache()

# monotonically_increasing_id() in spark assigns an unique id to each row.
# the ids are guaranteed to be monotonically increasing, but will have gaps
# between them. This is because under the hood a dataframe in spark has been
# divided up into multiple partitions which have been distributed to many workers
# in the cluster.

indexed_df = imputed_df.withColumn("index", F.monotonically_increasing_id())

duplicates = indexed_df.groupBy(["user", "game"]) \
  .agg(F.collect_list("index").alias("indices")) \
  .where(F.size("indices") > 1)

display(duplicates)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user</th><th>game</th><th>indices</th></tr></thead><tbody><tr><td>118664413</td><td>Grand Theft Auto San Andreas</td><td>List(360777253398, 1142461301257)</td></tr><tr><td>28472068</td><td>Grand Theft Auto III</td><td>List(1331439862120, 1640677507394)</td></tr><tr><td>28472068</td><td>Grand Theft Auto San Andreas</td><td>List(455266533540, 618475290777)</td></tr><tr><td>148362155</td><td>Grand Theft Auto San Andreas</td><td>List(790273982968, 1417339208185)</td></tr><tr><td>176261926</td><td>Sid Meier's Civilization IV Beyond the Sword</td><td>List(541165879545, 1649267441890)</td></tr><tr><td>71411882</td><td>Grand Theft Auto III</td><td>List(1116691497487, 42949673537)</td></tr><tr><td>50769696</td><td>Grand Theft Auto San Andreas</td><td>List(1022202216569, 171798691961)</td></tr><tr><td>59925638</td><td>Tom Clancy's H.A.W.X. 2</td><td>List(335007449120, 1073741824044)</td></tr><tr><td>71510748</td><td>Grand Theft Auto San Andreas</td><td>List(515396076160, 1443109012100)</td></tr><tr><td>28472068</td><td>Grand Theft Auto Vice City</td><td>List(1090921693502, 1228360646945)</td></tr><tr><td>33865373</td><td>Sid Meier's Civilization IV</td><td>List(962072674771, 309237645767)</td></tr><tr><td>176261926</td><td>Sid Meier's Civilization IV</td><td>List(618475290837, 188978561258)</td></tr></tbody></table></div>

# %%
duplicates.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">21</span><span class="ansired">]: </span>12
# </div>

# %% [markdown]
# So we do have 12 pairs of rows with same user-game key! Let's get those rows.

# %%
# first get a list of the row ids
# remember that our data are on workers in a distributed manner,
# therefore we cannot directly access them. Instead they need to
# be brought back to the driver of the cluster, which is our gateway
# to all the workers. collect() is the method to do that.

dupe_pairs = duplicates.select("indices").collect()

dupe_indices = []
for pair in dupe_pairs:
  dupe_indices.extend(pair[0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# notice the elements in dupe pairs here after collect() back to driver
# those are spark structs, used to represent a record in dataframe and are similar 
# to python's named tuples.

dupe_pairs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">10</span><span class="ansired">]: </span>
# [Row(indices=[360777253398, 1142461301257]),
#  Row(indices=[1331439862120, 1640677507394]),
#  Row(indices=[455266533540, 618475290777]),
#  Row(indices=[790273982968, 1417339208185]),
#  Row(indices=[541165879545, 1649267441890]),
#  Row(indices=[1116691497487, 42949673537]),
#  Row(indices=[1022202216569, 171798691961]),
#  Row(indices=[335007449120, 1073741824044]),
#  Row(indices=[515396076160, 1443109012100]),
#  Row(indices=[1090921693502, 1228360646945]),
#  Row(indices=[962072674771, 309237645767]),
#  Row(indices=[618475290837, 188978561258])]
# </div>

# %%
# now we have a flattened list of indices which
# can be used for filtering

dupe_indices
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">11</span><span class="ansired">]: </span>
# [360777253398,
#  1142461301257,
#  1331439862120,
#  1640677507394,
#  455266533540,
#  618475290777,
#  790273982968,
#  1417339208185,
#  541165879545,
#  1649267441890,
#  1116691497487,
#  42949673537,
#  1022202216569,
#  171798691961,
#  335007449120,
#  1073741824044,
#  515396076160,
#  1443109012100,
#  1090921693502,
#  1228360646945,
#  962072674771,
#  309237645767,
#  618475290837,
#  188978561258]
# </div>

# %%
display(indexed_df.where(F.col("index").isin(dupe_indices)).orderBy(F.col("user"), F.col("game")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user</th><th>game</th><th>play</th><th>index</th></tr></thead><tbody><tr><td>28472068</td><td>Grand Theft Auto III</td><td>0.4</td><td>1331439862120</td></tr><tr><td>28472068</td><td>Grand Theft Auto III</td><td>0.1</td><td>1640677507394</td></tr><tr><td>28472068</td><td>Grand Theft Auto San Andreas</td><td>0.2</td><td>455266533540</td></tr><tr><td>28472068</td><td>Grand Theft Auto San Andreas</td><td>0.7</td><td>618475290777</td></tr><tr><td>28472068</td><td>Grand Theft Auto Vice City</td><td>0.4</td><td>1090921693502</td></tr><tr><td>28472068</td><td>Grand Theft Auto Vice City</td><td>5.3</td><td>1228360646945</td></tr><tr><td>33865373</td><td>Sid Meier's Civilization IV</td><td>2.0</td><td>962072674771</td></tr><tr><td>33865373</td><td>Sid Meier's Civilization IV</td><td>135.0</td><td>309237645767</td></tr><tr><td>50769696</td><td>Grand Theft Auto San Andreas</td><td>3.1</td><td>1022202216569</td></tr><tr><td>50769696</td><td>Grand Theft Auto San Andreas</td><td>10.9</td><td>171798691961</td></tr><tr><td>59925638</td><td>Tom Clancy's H.A.W.X. 2</td><td>7.1</td><td>1073741824044</td></tr><tr><td>59925638</td><td>Tom Clancy's H.A.W.X. 2</td><td>0.3</td><td>335007449120</td></tr><tr><td>71411882</td><td>Grand Theft Auto III</td><td>0.2</td><td>1116691497487</td></tr><tr><td>71411882</td><td>Grand Theft Auto III</td><td>1.1</td><td>42949673537</td></tr><tr><td>71510748</td><td>Grand Theft Auto San Andreas</td><td>0.2</td><td>515396076160</td></tr><tr><td>71510748</td><td>Grand Theft Auto San Andreas</td><td>0.6</td><td>1443109012100</td></tr><tr><td>118664413</td><td>Grand Theft Auto San Andreas</td><td>0.2</td><td>1142461301257</td></tr><tr><td>118664413</td><td>Grand Theft Auto San Andreas</td><td>1.9</td><td>360777253398</td></tr><tr><td>148362155</td><td>Grand Theft Auto San Andreas</td><td>13.8</td><td>790273982968</td></tr><tr><td>148362155</td><td>Grand Theft Auto San Andreas</td><td>12.5</td><td>1417339208185</td></tr><tr><td>176261926</td><td>Sid Meier's Civilization IV</td><td>0.2</td><td>188978561258</td></tr><tr><td>176261926</td><td>Sid Meier's Civilization IV</td><td>14.6</td><td>618475290837</td></tr><tr><td>176261926</td><td>Sid Meier's Civilization IV Beyond the Sword</td><td>0.4</td><td>541165879545</td></tr><tr><td>176261926</td><td>Sid Meier's Civilization IV Beyond the Sword</td><td>564.0</td><td>1649267441890</td></tr></tbody></table></div>

# %% [markdown]
# So for those user-game pairs, multiple hours of play got mixed in. Let's combine each pair into one by adding the hours.

# %%
fixed_df = imputed_df.groupBy(["user", "game"]) \
  .agg(F.sum("play").alias("play"))

fixed_df.count() # now we have the expected number of records
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>128804
# </div>

# %%
fixed_df.printSchema()  # check if you have all the columns you need
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- user: integer (nullable = true)
# -- game: string (nullable = true)
# -- play: double (nullable = true)
#
# </div>

# %% [markdown]
# #### Replace actual hours played with percentage of hours on a game for each user

# %%
user_window = Window.partitionBy("user")
steam_play_pcnt = fixed_df \
  .withColumn("total_user_time", F.sum("play").over(user_window)) \
  .withColumn("percent_time", (lambda a, b: (a / b)*100)(F.col("play"), F.col("total_user_time"))) \
  .drop("total_user_time")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(steam_play_pcnt)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user</th><th>game</th><th>play</th><th>percent_time</th></tr></thead><tbody><tr><td>16167221</td><td>Half-Life 2 Episode One</td><td>7.0</td><td>0.688062122180174</td></tr><tr><td>16167221</td><td>ShareX</td><td>0.05</td><td>0.0049147294441441005</td></tr><tr><td>16167221</td><td>Half-Life 2 Lost Coast</td><td>0.6</td><td>0.0589767533297292</td></tr><tr><td>16167221</td><td>Blender 2.76b</td><td>0.05</td><td>0.0049147294441441005</td></tr><tr><td>16167221</td><td>Anno 1404</td><
td><td>11.6</td><td>9.228321400159109</td></tr><tr><td>35264447</td><td>BookWorm Deluxe</td><td>6.7</td><td>5.330151153540175</td></tr><tr><td>35264447</td><td>Half-Life 2 Deathmatch</td><td>0.05</td><td>0.039777247414478925</td></tr><tr><td>35264447</td><td>BookWorm Adventures Volume 2</td><td>107.0</td><td>85.12330946698489</td></tr><tr><td>35264447</td><td>Peggle Deluxe</td><td>0.05</td><td>0.039777247414478925</td></tr><tr><td>35264447</td><t ...

# %%
steam_play_pcnt.select("percent_time").summary().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+
# summary|        percent_time|
# +-------+--------------------+
#   count|              128804|
#    mean|   9.621595602621037|
#  stddev|  25.669253790243385|
#     min|4.289765049568239...|
#     25%|0.006122573930080209|
#     50%| 0.10256410256410256|
#     75%|  1.8124150430448571|
#     max|               100.0|
# +-------+--------------------+
#
# </div>

# %% [markdown]
# Keep the original ```play``` column - maybe we can build a recommender on each of ```play``` and ```percent_time```, and compare their performance, and see if what we did makes a difference.

# %%
# write the above data to csv for future use
#steam_play_pcnt.write.mode("overwrite").csv("dbfs:/FileStore/tables/steam_200k_hours_percent_20190305.csv", header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Before building the recommender, here is an optional step - indexing the game names with integers
#
# Based on [doc](https://apple.github.io/turicreate/docs/api/generated/turicreate.recommender.create.html#turicreate.recommender.create) of ```turicreate.recommender.create```, the user ID and item ID columns can be either ```int``` or ```str```, meaning that keeping the game title as is should be fine. Here let's do an extra step that indexes those strings with integers. (Maybe when we feel less lazy we can try ```spark.ml```'s recommender on it too.)
#
# However indexing is essential when you build models with Spark's machine learning libraries.

# %%
from pyspark.ml.feature import StringIndexer
from pyspark.sql.types import IntegerType

indexer = StringIndexer(inputCol="game", outputCol="game_index", stringOrderType="frequencyDesc")
steam_play_games_indexed = indexer.fit(steam_play_pcnt).transform(steam_play_pcnt) \
  .select("user", "game", F.col("game_index").cast(IntegerType()), "percent_time")

display(steam_play_games_indexed)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user</th><th>game</th><th>game_index</th><th>percent_time</th></tr></thead><tbody><tr><td>16167221</td><td>Half-Life 2 Episode One</td><td>30</td><td>0.688062122180174</td></tr><tr><td>16167221</td><td>ShareX</td><td>1969</td><td>0.0049147294441441005</td></tr><tr><td>16167221</td><td>Half-Life 2 Lost Coast</td><td>4</td><td>0.0589767533297292</td></tr><tr><td>16167221</td><td>Blender 2.76b</td><td>475</td><td>0.0049147294441441005</td></tr><tr><td>16167221</td><td>Anno 1404</td><td>1568</td><td>0.0049147294441441005</td></tr><tr><td>16167221</td><td>Counter-Strike</td><td>7</td><td>3.44031061090087</td></tr><tr><td>16167221</td><td>Portal</td><td>19</td><td>0.1867597188774758</td></tr><tr><td>16167221</td><td>Little Big Adventure 2</td><td>4780</td><td>0.009829458888288201</td></tr><tr><td>16167221</td><td>Dark Messiah of Might & Magic Multi-Player</td><td>528</td><td>0.12778296554774662</td></tr><tr><td>16167221</td><td>Fuse</td><td>1324</td><td>0.0049147294441441005</td></tr><tr><td>16167221</td><td>Fable III</td><td>1082</td><td>10.32093183270261</td></tr><tr><td>16167221</td><td>Hitman Blood Money</td><td>
</td></tr><tr><td>Left 4 Dead</td><td>57</td></tr><tr><td>PAYDAY The Heist</td><td>58</td></tr><tr><td>Grand Theft Auto V</td><td>59</td></tr><tr><td>Arma 2</td><td>60</td></tr><tr><td>Half-Life Deathmatch Source</td><td>61</td></tr><tr><td>Empire Total War</td><td>62</td></tr><tr><td>APB Reloaded</td><td>63</td></tr><tr><td>Saints Row The Third</td><td>64</td></tr><tr><td>The Witcher 2 Assassins of Kings Enhanced Edition</td><td>65</td></tr><tr><td>Tomb Raider</td><td>66</td></tr><tr><td>FreeStyle2 Street Basketball</td><td>67</td></tr><tr><td>Don't Starve Together Beta</td><td>68</td></tr><tr><td>Call of Duty Black Ops - Multiplayer</td><td>69</td></tr><tr><td>Call of Duty Black Ops</td><td>70</td></tr><tr><td>Arma 2 Operation Arrowhead</td><td>71</td></tr><tr><td>Arma 2 Operation Arrowhead Beta (Obsolete)</td><td>72</td></tr><tr><td>DayZ</td><td>73</td></tr><tr><td>theHunter</td><td>74</td></tr><tr><td>Clicker Heroes</td><td>75</td></tr><tr><td>Tom Clancy's Ghost Recon Phantoms - EU</td><td>76</td></tr><tr><td>Just Cause 2</td><td>77</td></tr><tr><td>Sniper Elite V2</td><td>78</td></tr><tr><td>Sid Meier's Civilization V Brave New World</td><td>79</td></tr ...

# %%
#game_lookup.write.mode("overwrite").csv("dbfs:/FileStore/tables/steam_games_lookup_20190305.csv", header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Item-Item Similarity Recommender in ```turicreate```

# %%
steam_play_pd = steam_play_games_indexed \
  .select("user", "game_index", "percent_time") \
  .toPandas()

steam_sframe = tc.SFrame(steam_play_pd)
steam_sframe
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">22</span><span class="ansired">]: </span>
# Columns:
# 	user	int
# 	game_index	int
# 	percent_time	float
#
# Rows: 128804
#
# Data:
# +----------+------------+-----------------------+
#    user   | game_index |      percent_time     |
# +----------+------------+-----------------------+
#  16167221 |     30     |   0.688062122180174   |
#  16167221 |    1969    | 0.0049147294441441005 |
#  16167221 |     4      |   0.0589767533297292  |
#  16167221 |    475     | 0.0049147294441441005 |
#  16167221 |    1568    | 0.0049147294441441005 |
#  16167221 |     7      |    3.44031061090087   |
#  16167221 |     19     |   0.1867597188774758  |
#  16167221 |    4780    |  0.009829458888288201 |
#  16167221 |    528     |  0.12778296554774662  |
#  16167221 |    1324    | 0.0049147294441441005 |
# +----------+------------+-----------------------+
# [128804 rows x 3 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.
# </div>

# %%
# You can do a train-test split with the below function
# but for now let's skip this and construct the matrix with all data

#train_sframe, test_sframe = tc.recommender.util.random_split_by_user(steam_sframe, user_id="user", item_id="game_index", max_num_users=500)

# %% [markdown]
# Below creates a recommender that uses item-item similarities based on users in common ([doc](https://apple.github.io/turicreate/docs/api/generated/turicreate.recommender.item_similarity_recommender.create.html#turicreate.recommender.item_similarity_recommender.create)). You can choose from 3 similarity measurements for ```similarity type``` - ```jaccard```, ```cosine``` and ```pearson```. More details can be found [here](https://apple.github.io/turicreate/docs/api/generated/turicreate.recommender.item_similarity_recommender.ItemSimilarityRecommender.html).

# %%
item_item_reco = tc.recommender.item_similarity_recommender.create( \
    steam_sframe, user_id="user", item_id="game_index", \
    target="percent_time", similarity_type="pearson")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Preparing data set.
#     Data has 128804 observations with 12393 users and 5155 items.
#     Data prepared in: 0.128103s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
#  Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
#  953us                          | 8          |
#  4.271ms                        | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
#  Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
#  362.613ms                           | 0                | 0               |
#  1.09s                               | 100              | 5155            |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 2.13041s
# </div>

# %%
# this gives for each game its top 64 closest neighbours
# you can change the number of neighbours to calculate

similar_games = item_item_reco.get_similar_items()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# for example to check some results
game_lookup_sframe = tc.SFrame(game_lookup.toPandas())

similar_games_named = similar_games.join(game_lookup_sframe, on="game_index", how="left") \
  .join(game_lookup_sframe, on={"similar":"game_index"}, how="left") \
  .rename({"game.1":"similar_game"}, True) \
  .select_columns(["game_index", "game", "similar", "similar_game", "score", "rank"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
similar_games_named.print_rows(num_rows=10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+-------------------------+---------+
#  game_index |           game          | similar |
# +------------+-------------------------+---------+
#      30     | Half-Life 2 Episode One |    16   |
#      30     | Half-Life 2 Episode One |    61   |
#      30     | Half-Life 2 Episode One |    38   |
#      30     | Half-Life 2 Episode One |    4    |
#      30     | Half-Life 2 Episode One |   1201  |
#      30     | Half-Life 2 Episode One |   1247  |
#      30     | Half-Life 2 Episode One |   657   |
#      30     | Half-Life 2 Episode One |    19   |
#      30     | Half-Life 2 Episode One |    0    |
#      30     | Half-Life 2 Episode One |    40   |
# +------------+-------------------------+---------+
# +-------------------------------+----------------------+------+
#           similar_game         |        score         | rank |
# +-------------------------------+----------------------+------+
#           Half-Life 2          | 0.12549090385437012  |  1   |
#   Half-Life Deathmatch Source  | 0.11610668897628784  |  2   |
#     Half-Life 2 Episode Two    | 0.09407681226730347  |  3   |
#      Half-Life 2 Lost Coast    | 0.07755649089813232  |  4   |
#        SEGA Bass Fishing       | 0.07511734962463379  |  5   |
#            Crazy Taxi          |  0.0699281096458435  |  6   |
#  Battlefield Bad Company 2 ... | 0.05807262659072876  |  7   |
#              Portal            | 0.055140018463134766 |  8   |
#              Dota 2            | 0.04800313711166382  |  9   |
#       Half-Life Blue Shift     | 0.04686927795410156  |  10  |
# +-------------------------------+----------------------+------+
# [39752 rows x 6 columns]
#
# </div>

# %% [markdown]
# Woah the above results actually look quite nice! Let's check another one:

# %%
similar_games_named.filter_by("Grand Theft Auto III", "game").print_rows(num_rows=10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
tr><tr><td>194670621</td><td>Gear Up</td><td>208</td><td>0.005783355502862762</td></tr><tr><td>194670621</td><td>Red Crucible Firestorm</td><td>389</td><td>0.1966340870973339</td></tr><tr><td>194670621</td><td>Tactical Intervention</td><td>161</td><td>3.238679081603147</td></tr><tr><td>194670621</td><td>Besiege</td><td>270</td><td>0.4511017292232954</td></tr><tr><td>194670621</td><td>Max Payne 3</td><td>205</td><td>0.0462668440229021</td></tr><tr><td>194670621</td><td>Portal 2</td><td>20</td><td>2.2208085130993007</td></tr><tr><td>194670621</td><td>Goat Simulator</td><td>163</td><td>0.8559366144236888</td></tr><tr><td>194670621</td><td>Source Filmmaker</td><td>406</td><td>0.2313342201145105</td></tr><tr><td>194670621</td><td>Toribash</td><td>155</td><td>0.3470013301717657</td></tr><tr><td>194670621</td><td>Metaverse Construction Kit</td><td>3125</td><td>0.011566711005725525</td></tr><tr><td>194670621</td><td>Hurtworld</td><td>1952</td><td>0.2313342201145105</td></tr><tr><td>194670621</td><td>Subnautica</td><td>1504</td><td>0.3470013301717657</td></tr><tr><td>194670621</td><td>Plug & Play</td><td>2444</td><td>0.02313342201145105</td></tr><tr><td>194670621</td><td>World of Guns Gun Disassembly</td><td>203</td><td>0.16193395408015732</td></tr><tr><td>194670621</td><td>Dirty Bomb</td><td>49</td><td>0.005783355502862762</td></tr><tr><td>194670621</td><td>Fistful of Frags</td><td>152</td><td>0.38170146318894227</td></tr></tbody></table></div>

# %%
recs = item_item_reco.recommend()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">recommendations finished on 1000/12393 queries. users per second: 36444.5
# recommendations finished on 2000/12393 queries. users per second: 38443.1
# recommendations finished on 3000/12393 queries. users per second: 40264.7
# recommendations finished on 4000/12393 queries. users per second: 40804.7
# recommendations finished on 5000/12393 queries. users per second: 40551.5
# recommendations finished on 6000/12393 queries. users per second: 40761.7
# recommendations finished on 7000/12393 queries. users per second: 41040.3
# recommendations finished on 8000/12393 queries. users per second: 41200.4
# recommendations finished on 9000/12393 queries. users per second: 41484.4
# recommendations finished on 10000/12393 queries. users per second: 41646.9
# recommendations finished on 11000/12393 queries. users per second: 41859.5
# recommendations finished on 12000/12393 queries. users per second: 41678.4
# </div>

# %%
recs_named = recs.join(game_lookup_sframe, on="game_index", how="left")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
recs_named.filter_by(194670621, "user").print_rows(num_rows=50)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+------------+-------+------+--------------------------------+
#     user   | game_index | score | rank |              game              |
# +-----------+------------+-------+------+--------------------------------+
#  194670621 |    4558    | 100.0 |  1   | TyranoBuilder Visual Novel...  |
#  194670621 |    4037    | 100.0 |  2   |     Don Bradman Cricket 14     |
#  194670621 |    4789    | 100.0 |  3   |            RECYCLE             |
#  194670621 |    4225    | 100.0 |  4   |         Funk of Titans         |
#  194670621 |    4753    | 100.0 |  5   |          Xpand Rally           |
#  194670621 |    4162    | 100.0 |  6   |            Insane 2            |
#  194670621 |    3374    | 100.0 |  7   | Nobunaga&apos;s Ambition Souzou...  |
#  194670621 |    4977    | 100.0 |  8   |          Diaper Dash           |
#  194670621 |    4301    | 100.0 |  9   |           Jack Keane           |
#  194670621 |    3651    | 100.0 |  10  | Rugby League Team Manager 2015 |
# +-----------+------------+-------+------+--------------------------------+
# [10 rows x 5 columns]
#
# </div>

# %% [markdown]
# **SOMETHING IS NOT RIGHT HEREEEEEE!!!!!** Since it looks like everyone is getting pretty much the same recommendations! (COMBAK and figure this out)

# %% [markdown]
# ### Spark's ALS-based recommender in ```pyspark.ml.recommendation```
#
# (Below paragraph is an exerpt from [Spark's doc](https://spark.apache.org/docs/2.2.0/ml-collaborative-filtering.html#explicit-vs-implicit-feedback).)
#
# Collaborative filtering is commonly used for recommender systems. These techniques aim to fill in the missing entries of a user-item association matrix. ```spark.ml``` currently supports model-based collaborative filtering, in which users and products are described by a small set of latent factors that can be used to predict missing entries. spark.ml uses the **Alternating Least Squares (ALS)** algorithm to learn these latent factors.
#
# To see a list of hyperparameters to tune, see the Spark doc linked.

# %%
# back to our original indexed dataset again
steam_play_games_indexed.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- user: integer (nullable = true)
# -- game: string (nullable = true)
# -- game_index: integer (nullable = true)
# -- percent_time: double (nullable = true)
#
# </div>

# %%
from pyspark.ml.recommendation import ALS

# init the model
als = ALS(maxIter=6, regParam=0.01, implicitPrefs=True, \
  userCol="user", itemCol="game_index", ratingCol="percent_time")

# fit the model to our data
model = als.fit(steam_play_games_indexed)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# get recommendations for all users (50 per user)
user_recs = model.recommendForAllUsers(50)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(user_recs)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user</th><th>recommendations</th></tr></thead><tbody><tr><td>46014950</td><td>List(List(62, 0.4097474), List(47, 0.36577514), List(44, 0.3651413), List(119, 0.35992107), List(108, 0.35621178), List(70, 0.33824965), List(157, 0.33312264), List(69, 0.33048403), List(45, 0.32422546), List(217, 0.30283773), List(143, 0.30271062), List(139, 0.2663434), List(528, 0.2614322), List(165, 0.24875428), List(524, 0.24753352), List(415, 0.24231088), List(1272, 0.24076268), List(148, 0.23916933), List(26, 0.23000166), List(91, 0.22805157), List(11, 0.22324729), List(138, 0.21799096), List(3, 0.21700536), List(469, 0.21482116), List(144, 0.21153821), List(305, 0.20984766), List(142, 0.2002224), List(767, 0.19996227), List(249, 0.19602063), List(337, 0.19270203), List(24, 0.19106393), List(276, 0.1894375), List(223, 0.18591079), List(141, 0.18308331), List(1, 0.18279698), List(369, 0.1761222), List(437, 0.17552227), List(434, 0.1733752), List(1531, 0.17231895), List(59, 0.17184648), List(568, 0.17058797), List(131, 0.17052831), List(438, 0.1690799), List(327, 0.16868503), List(509, 0.16575377), List(206, 0.1642923), List(15, 0.16329977), List(17, 0.16086766), List(397, 0.15810794), List(54, 0.15732178))</td></tr><tr><td>95059220</td><td>List(List(81, 0.8573685), List(44, 0.8435464), List(3, 0.82290286), List(82, 0.81529534), List(45, 0.76698965), List(69, 0.71641), List(70, 0.70006645), List(134, 0.5366995), List(6, 0.5203797), List(17, 0.4679038), List(498, 0.4380998), List(7, 0.41699174), List(288, 0.37876046), List(0, 0.37658644), List(75, 0.36454055), List(136, 0.35558406), List(119, 0.35207695), List(285, 0.3473496), List(162, 0.34590295), List(27, 0.33899525), List(51, 0.3378387), List(71, 0.32256603), List(292, 0.30925202), List(499, 0.3088986), List(26, 0.2995578), List(1148, 0.2919853), List(95, 0.28908107), List(66, 0.28671357), List(13, 0.27579844), List(941, 0.26085967), List(261, 0.25468442), List(206, 0.25277108), List(142, 0.25239122), List(820, 0.2503833), List(58, 0.247715), List(91, 0.24329776), List(451, 0.24235009), List(77, 0.24121067), List(20, 0.23909907), List(337, 0.23804386), List(114, 0.23642543), List(148, 0.22996494), List(14, 0.2287651), List(132, 0.22744563), List(54, 0.22522977), List(294, 0.22388673), List(1239, 0.22338107), List(399, 0.22185202), List(434, 0.21892922), List(5, 0.215964))</td></tr><tr><td>108219790</td><td>List(List(81, 0.8784238), List(82, 0.84762806), List(44, 0.81645846), List(3, 0.8088436), List(45, 0.75058454), List(69, 0.6867235), List(70, 0.67643946), List(134, 0.50367105), List(17, 0.49404353), List(498, 0.46468657), List(6, 0.3919897), List(75, 0.35690814), List(0, 0.35172808), List(119, 0.35128728), List(136, 0.33885458), List(499, 0.33671093), List(288, 0.32799202), List(51, 0.32789418), List(285, 0.31578875), List(27, 0.30899683), List(95, 0.3070007), List(91, 0.30580086), List(292, 0.30570883), List(7, 0.30517316), List(162, 0.29236874), List(71, 0.28887516), List(1239, 0.2768095), List(618, 0.26738197), List(206, 0.2587881), List(1148, 0.25389767), List(261, 0.25178257), List(451, 0.2463771), List(941, 0.23928693), List(820, 0.23646748), List(128, 0.23176436), List(148, 0.22970505), List(66, 0.22782525), List(337, 0.22579432), List(58, 0.2233685), List(872, 0.22304533), List(26, 0.22228669), List(114, 0.22202477), List(78, 0.21400607), List(99, 0.21360742), List(132, 0.21266124), List(142, 0.21172033), List(276, 0.20603572), List(178, 0.20356327), List(1915, 0.20126681), List(279, 0.20113876))</td></tr><tr><td>128412180</td><td>List(List(1, 1.2694958), List(217, 0.86428523), List(157, 0.47661114), List(143, 0.38315538), List(62, 0.3593001), List(148, 0.34873068), List(108, 0.34543788), List(86, 0.34247148), List(528, 0.33649987), List(48, 0.33224446), List(233, 0.32993615), List(524, 0.30731243), List(369, 0.30344233), List(509, 0.30159515), List(397, 0.2986431), ...

# %%
user_recs.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">111</span><span class="ansired">]: </span>DataFrame[user: int, recommendations: array&lt;struct&lt;game_index:int,rating:float&gt;&gt;]
# </div>

# %% [markdown]
# The recommendations and rankings are all in a dictionary for each user right now. To join the game indices back with their titles, explode the dictionary items into rows, and then separate them into two columns - ```reco``` and ```rank```.

# %%
# udf is user-defined function
# by registering your own function as an udf
# spark can then apply it on dataframe columns
# (distribute to RDDs on workers)

from pyspark.sql.functions import udf
from pyspark.sql.types import IntegerType, FloatType

# second parameter specifies the return type
get_index = udf(lambda x: x["game_index"], IntegerType())
get_rating = udf(lambda x: x["rating"], FloatType())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
user_recs_with_title = user_recs \
  .withColumn("reco_and_rank", F.explode("recommendations")) \
  .withColumn("game_reco", get_index(F.col("reco_and_rank"))) \
  .withColumn("game_rating", get_rating(F.col("reco_and_rank"))) \
  .drop("recommendations") \
  .drop("reco_and_rank")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(user_recs_with_title)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
#  Row(user=194670621, game=&apos;Chivalry Medieval Warfare&apos;, game_index=93, percent_time=0.4279683072118444),
#  Row(user=194670621, game=&apos;DCS World&apos;, game_index=303, percent_time=0.005783355502862762),
#  Row(user=194670621, game=&apos;Minecraft Story Mode - A Telltale Games Series&apos;, game_index=2171, percent_time=0.5667688392805508),
#  Row(user=194670621, game=&apos;Robocraft&apos;, game_index=12, percent_time=0.05783355502862762),
#  Row(user=194670621, game=&apos;Unturned&apos;, game_index=2, percent_time=0.034700133017176574),
#  Row(user=194670621, game=&apos;Only If&apos;, game_index=338, percent_time=0.02313342201145105),
#  Row(user=194670621, game=&apos;LEGO The Hobbit&apos;, game_index=1233, percent_time=0.005783355502862762),
#  Row(user=194670621, game=&quot;Deus Ex Human Revolution - Director&apos;s Cut&quot;, game_index=260, percent_time=0.6014689722977273),
#  Row(user=194670621, game=&apos;Portal Stories Mel&apos;, game_index=552, percent_time=0.05783355502862762),
#  Row(user=194670621, game=&apos;War Thunder&apos;, game_index=18, percent_time=0.0925336880458042),
#  Row(user=194670621, game=&apos;The Way of Life Free Edition&apos;, game_index=604, percent_time=0.011566711005725525),
#  Row(user=194670621, game=&apos;No More Room in Hell&apos;, game_index=25, percent_time=0.33543461916604017),
#  Row(user=194670621, game=&quot;Garry&apos;s Mod&quot;, game_index=10, percent_time=22.78642068127928),
#  Row(user=194670621, game=&apos;Gear Up&apos;, game_index=208, percent_time=0.005783355502862762),
#  Row(user=194670621, game=&apos;Red Crucible Firestorm&apos;, game_index=389, percent_time=0.1966340870973339),
#  Row(user=194670621, game=&apos;Tactical Intervention&apos;, game_index=161, percent_time=3.238679081603147),
#  Row(user=194670621, game=&apos;Besiege&apos;, game_index=270, percent_time=0.4511017292232954),
#  Row(user=194670621, game=&apos;Max Payne 3&apos;, game_index=205, percent_time=0.0462668440229021),
#  Row(user=194670621, game=&apos;Portal 2&apos;, game_index=20, percent_time=2.2208085130993007),
#  Row(user=194670621, game=&apos;Goat Simulator&apos;, game_index=163, percent_time=0.8559366144236888),
#  Row(user=194670621, game=&apos;Source Filmmaker&apos;, game_index=406, percent_time=0.2313342201145105),
#  Row(user=194670621, game=&apos;Toribash&apos;, game_index=155, percent_time=0.3470013301717657),
#  Row(user=194670621, game=&apos;Metaverse Construction Kit&apos;, game_index=3125, percent_time=0.011566711005725525),
#  Row(user=194670621, game=&apos;Hurtworld&apos;, game_index=1952, percent_time=0.2313342201145105),
#  Row(user=194670621, game=&apos;Subnautica&apos;, game_index=1504, percent_time=0.3470013301717657),
#  Row(user=194670621, game=&apos;Plug &amp; Play&apos;, game_index=2444, percent_time=0.02313342201145105),
#  Row(user=194670621, game=&apos;World of Guns Gun Disassembly&apos;, game_index=203, percent_time=0.16193395408015732),
#  Row(user=194670621, game=&apos;Dirty Bomb&apos;, game_index=49, percent_time=0.005783355502862762),
#  Row(user=194670621, game=&apos;Fistful of Frags&apos;, game_index=152, percent_time=0.38170146318894227)]
# </div>

# %%
# display the user's recommendations
display(reco_results.filter(F.col("user") == u))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
><td>30</td><td>Half-Life 2 Episode One</td><td>0.31369576</td></tr><tr><td>194670621</td><td>48</td><td>Warface</td><td>0.3116537</td></tr><tr><td>194670621</td><td>146</td><td>Arma 3</td><td>0.31128195</td></tr><tr><td>194670621</td><td>26</td><td>Borderlands 2</td><td>0.3105833</td></tr><tr><td>194670621</td><td>5</td><td>Counter-Strike Source</td><td>0.2987085</td></tr><tr><td>194670621</td><td>38</td><td>Half-Life 2 Episode Two</td><td>0.29608965</td></tr><tr><td>194670621</td><td>55</td><td>Neverwinter</td><td>0.29595706</td></tr><tr><td>194670621</td><td>9</td><td>Half-Life 2 Deathmatch</td><td>0.29128844</td></tr><tr><td>194670621</td><td>71</td><td>Arma 2 Operation Arrowhead</td><td>0.27718392</td></tr><tr><td>194670621</td><td>75</td><td>Clicker Heroes</td><td>0.2701003</td></tr><tr><td>194670621</td><td>52</td><td>Marvel Heroes 2015</td><td>0.25722688</td></tr><tr><td>194670621</td><td>94</td><td>AdVenture Capitalist</td><td>0.25590622</td></tr><tr><td>194670621</td><td>141</td><td>ARK Survival Evolved</td><td>0.25416842</td></tr><tr><td>194670621</td><td>73</td><td>DayZ</td><td>0.24684836</td></tr><tr><td>194670621</td><td>177</td><td>H1Z1</td><td>0.24278094</td></tr><tr><td>194670621</td><td>86</td><td>Dead Island</td><td>0.2426382</td></tr><tr><td>194670621</td><td>96</td><td>Defiance</td><td>0.23812585</td></tr><tr><td>194670621</td><td>167</td><td>The Mighty Quest For Epic Loot</td><td>0.23736659</td></tr><tr><td>194670621</td><td>59</td><td>Grand Theft Auto V</td><td>0.2320945</td></tr><tr><td>194670621</td><td>64</td><td>Saints Row The Third</td><td>0.223697</td></tr></tbody></table></div>

# %% [markdown]
# This was only for one user. **Let's remove all the purchased games from recommendations for all users.**
#
# There are many ways doing this. One way is to gather each user's purchase and recommendations into two lists, and convert them to Python ```set```, which is fast for finding the differece between two collections (we want a resulting set the elements of which are in reco set but not in purchase history set).

# %%
# get each user's list of historical purchase

all_purchase_hist = steam_play_games_indexed \
  .select("user", "game_index").groupBy("user") \
  .agg(F.collect_list("game_index").alias("purchased_index"))

display(all_purchase_hist)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user</th><th>purchased_index</th></tr></thead><tbody><tr><td>16167221</td><td>List(30, 1969, 4, 475, 1568, 7, 19, 4780, 528, 1324, 1082, 341, 3573, 14, 3084, 16, 708, 406, 1081, 336, 1, 13, 139, 186, 2286, 408, 55, 8, 38, 471, 743, 524)</td></tr><tr><td>119310413</td><td>List(1451, 454, 116, 10, 64, 60, 936, 1413, 117, 185, 852, 143, 507, 723, 161, 441, 611, 11, 6, 1406, 1, 1485, 1466, 303, 1362, 1395, 1006, 58, 358, 31, 1480, 56, 142, 1357, 1284)</td></tr><tr><td>141774640</td><td>List(131, 585)</td></tr><tr><td>192170147</td><td>List(1070, 224, 1201, 186, 873, 504, 609, 16, 59, 1147, 29, 1151, 4, 678, 98, 705, 2589, 14, 2, 32, 197, 28, 22, 37, 73, 210, 2642, 1247, 278, 20, 837, 92, 21, 13, 5, 115, 40, 595, 141, 6, 1256, 
95059220</td><td>List(346, 342, 109, 666, 285, 337, 81, 288, 191, 82)</td></tr><tr><td>172976494</td><td>List(288, 144, 102, 201, 1210, 482, 285)</td></tr><tr><td>128412180</td><td>List(217)</td></tr><tr><td>161118595</td><td>List(868)</td></tr><tr><td>161408431</td><td>List(0)</td></tr><tr><td>204631355</td><td>List(2, 12, 1)</td></tr><tr><td>167193350</td><td>List(0)</td></tr><tr><td>299523550</td><td>List(2299)</td></tr><tr><td>148546383</td><td>List(0)</td></tr><tr><td>210362059</td><td>List(139)</td></tr><tr><td>197279094</td><td>List(84, 225, 2)</td></tr><tr ...

# %%
all_purchase_hist.cache()
reco_results.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">125</span><span class="ansired">]: </span>DataFrame[user: int, game_index: int, title: string, game_rating: float]
# </div>

# %%
# get each user's list of recommended items

all_reco_indices = reco_results \
  .select("user", "game_index").groupBy("user") \
  .agg(F.collect_list("game_index").alias("reco_index"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# check if number of users in the above two datasets match

print(all_purchase_hist.count())
print(all_reco_indices.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">12393
# 12393
# </div>

# %%
all_reco_indices.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">129</span><span class="ansired">]: </span>DataFrame[user: int, reco_index: array&lt;int&gt;]
# </div>

# %%
# join purchase history with recommendations on user id

purchase_and_reco = all_reco_indices.join(all_purchase_hist, ["user"], how="left")

# check if there are missing users in either column, the result is 0 so we are good to go!
purchase_and_reco.filter((F.col("reco_index").isNull()) | (F.col("purchased_index").isNull())).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">138</span><span class="ansired">]: </span>0
# </div>

# %%
display(purchase_and_reco)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user</th><th>reco_index</th><th>purchased_index</th></tr></thead><tbody><tr><td>46014950</td><td>List(62, 47, 44, 119, 108, 70, 157, 69, 45, 217, 143, 139, 528, 165, 524, 415, 1272, 148, 26, 91, 11, 138, 3, 469, 144, 305, 142, 767, 249, 337, 24, 276, 223, 141, 1, 369, 437, 434, 1531, 59, 568, 131, 438, 327, 509, 206, 15, 17, 397, 54)</td><td>List(1223)</td></tr><tr><td>95059220</td><td>List(81, 44, 3, 82, 45, 69, 70, 134, 6, 17, 498, 7, 288, 0, 75, 136, 119, 285, 162, 27, 51, 71, 292, 499, 26, 1148, 95, 66, 13, 941, 261, 206, 142, 820, 58, 91, 451, 77, 20, 337, 114, 148, 14, 132, 54, 294, 1239, 399, 434, 5)</td><td>List(346, 342, 109, 666, 285, 337, 81, 288, 191, 82)</td></tr><tr><td>108219790</td><td>List(81, 82, 44, 3, 45, 69, 70, 134, 17, 498, 6, 75, 0, 119, 136, 499, 288, 51, 285, 27, 95, 91, 292, 7, 162, 71, 1239, 618, 206, 1148, 261, 451, 941, 820, 128, 148, 66, 337, 58, 872, 26, 114, 78, 99, 132, 142, 276, 178, 1915, 279)</td><td>List(81, 82)</td></tr><tr><td>128412180</td><td>List(1, 217, 157, 143, 62, 148, 108, 86, 528, 48, 233, 524, 369, 509, 397, 708, 881, 2734, 215, 536, 845, 107, 330, 0, 287, 249, 734, 141, 1631, 365, 1782, 50, 119, 196, 437, 305, 164, 76, 269, 429, 52, 236, 15, 67, 1617, 434, 144, 1272, 963, 282)</td><td>List(217)</td></tr><tr><td>141774640</